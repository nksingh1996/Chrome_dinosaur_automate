# %% [markdown]
# # Automate Dinosaur

# %%
import cv2
from matplotlib import pyplot as plt
from selenium import webdriver
import os
import io
from PIL import Image
import numpy as np
import pyautogui
# import keyboard
import pandas as pd
from collections import Counter
import time
# %matplotlib inline

# %%
import cv2
from matplotlib import pyplot as plt
from selenium import webdriver
import os
import io
from PIL import Image
import numpy as np
import pyautogui
# import keyboard
import pandas as pd
from collections import Counter
import time
# %matplotlib inline

# %%
cap = cv2.VideoCapture()

# %%
q, w = cap.read()

# %%
cap.open(0)
cap.grab()
# Out:
# True

# %%
cap.release()

# %%
q, w = cap.retrieve()
plt.imshow(w)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e402fa7bb273> in <module>()
#       1 q, w = cap.retrieve()
# ----> 2 plt.imshow(w)
#       3 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
for i in range(10):
    time.sleep(10)
    q,w = cap.read()
    plt.imshow(w)
    plt.show()

# %%
cap.release()

# %%
pyautogui.press("up")

# %%
chrome = webdriver.Chrome()
chrome.get("https://apps")
# l = list()
for i in range(1000):
    q = chrome.get_screenshot_as_png()
    img = Image.open(io.BytesIO(q))
    ar = np.asarray(img)
    m = ar[126:165, 410:470].mean()
#     l.append([img, ar,dif, m])
    if m <= 248:
        pyautogui.press("up")

# %%
df = pd.DataFrame(l, columns=["image", "array", "difference", "m"])

# %%
Counter(df["m"]).most_common()

# %%
# df.to_pickle("dinasour_data2.pickle")
